# %% [markdown]
# <a href="https://colab.research.google.com/github/septianwijaya45/PVCK_Modul-3-5-/blob/main/Modul_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %%
print(' Mengubah tingkat kecerahan citra ')
print(' -------------------------------- ')

try:
  brightness = int(input('Masukkan Nilai Kecerahan: '))
except ValueError:
  print('Error, Not a Number')

original = cv.imread('/content/drive/MyDrive/rose_pink.png')
brighness_image = np.zeros(original.shape, original.dtype)

# akses per piksel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brighness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

# cara simple tanpa for loop
# brightness_image = cv.convertScaleAbs(original, beta=brightness)

final_frame = cv.hconcat((original, brighness_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
#  --------------------------------
# Masukkan Nilai Kecerahan: 61
# <PIL.Image.Image image mode=RGB size=1000x750 at 0x7F12387A4510>

# %%
print(' Mengubah tingkat kecerahan citra ')
print(' -------------------------------- ')

try:
  brightness = int(input('Masukkan Nilai Kecerahan: '))
except ValueError:
  print('Error, Not a Number')

original2 = cv.imread('/content/drive/MyDrive/female.tiff')
brighness_image2 = np.zeros(original2.shape, original2.dtype)


for a in range(original2.shape[0]):
  for b in range(original2.shape[1]):
    for d in range(original2.shape[2]):
      brighness_image2[a,b,d] = np.clip(original2[a,b,d] + brightness, 0, 255)


final_frame = cv.hconcat((original2, brighness_image2))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
#  --------------------------------
# Masukkan Nilai Kecerahan: 40
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7F12386EB490>

# %%
print(' Mengubah tingkat kecerahan citra ')
print(' -------------------------------- ')

try:
  brightness = int(input('Masukkan Nilai Kecerahan: '))
except ValueError:
  print('Error, Not a Number')

original3 = cv.imread('/content/drive/MyDrive/mandrill.tiff')
brighness_image3 = np.zeros(original3.shape, original3.dtype)


for a in range(original3.shape[0]):
  for b in range(original3.shape[1]):
    for d in range(original3.shape[2]):
      brighness_image3[a,b,d] = np.clip(original3[a,b,d] + brightness, 1, 122)


final_frame = cv.hconcat((original3, brighness_image3))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
#  --------------------------------
# Masukkan Nilai Kecerahan: 33
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x7F12386352D0>
